# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalPethkar/YBI-FOUNDCTION--2-MONTH--INTNSHIP/blob/main/09Icecream_Revenue_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1 : import library
import pandas as pd


# Step 2 : import data
icecream = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Ice%20Cream.csv')


# Step 3 : define target (y) and features (X)


icecream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
y = icecream['Revenue']


X = icecream[['Temperature']]

# %%
# Step 4 : train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.7, random_state=2529)

# %%
import sys
print(sys.executable)
# Out:
# E:\Anaconda\envs\data_env\python.exe

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.7, random_state=2529
)

# %%
import sklearn  # already installed on Kaggle

# %%
pip install scikit-learn
# Out:
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    --------------- ------------------------ 3.4/8.9 MB 18.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.3/8.9 MB 17.5 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/8.9 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 11.0 MB/s  0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.9/41.3 MB 14.0 MB/s eta 0:00:03
#    ----- ---------------------------------- 6.0/41.3 MB 14.8 MB/s eta 0:00:03
#    --------- ------------------------------ 9.4/41.3 MB 15.4 MB/s eta 0:00:03
#    ------------ --------------------------- 12.8/41.3 MB 15.2 MB/s eta 0:00:02
# ...

# %%
# check shape of train and test sample
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((350, 1), (150, 1), (350,), (150,))

# %%
# Step 5 : select model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Step 6 : train or fit model
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(42.444772590839705)

# %%
model.coef_
# Out:
# array([21.54587147])

# %%
# Step 7 : predict model
y_pred = model.predict(X_test)


y_pred
# Out:
# array([645.7291738 , 380.7149547 , 180.33835001, 247.13055157,
#        415.18834905, 283.75853308, 372.09660611, 671.58421957,
#        675.89339386, 684.51174245, 531.536055  , 613.41036659,
#        361.32367037, 303.1498174 , 158.79247854, 473.36220203,
#        611.25577945, 615.56495374, 512.14477068, 805.16862269,
#        268.67642305, 441.04339482, 436.73422053, 861.18788852,
#        531.536055  , 216.96633151, 725.44889825, 311.76816599,
#        505.68100924, 466.89844059, 684.51174245, 960.29889729,
#        550.92733933, 615.56495374, 367.78743182, 404.41541332,
#        413.03376191, 662.96587098, 876.26999855, 544.46357788,
#        811.63238414, 686.6663296 , 486.28972491, 322.54110172,
#        637.11082521, 798.70486125, 438.88880767, 790.08651266,
#        684.51174245, 497.06266065, 380.7149547 , 479.82596347,
#        479.82596347, 563.85486221, 665.12045813, 453.9709177 ,
#        688.82091675, 647.88376095, 391.48789043, 662.96587098,
# ...

# %%
# Step 8 : model accuracy
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error


mean_absolute_error(y_test,y_pred)
# Out:
# 19.138687444270737

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.042214848219420134

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 583.7362763558341
