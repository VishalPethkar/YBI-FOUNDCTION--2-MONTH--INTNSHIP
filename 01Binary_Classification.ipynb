# %% [markdown]
# <a href="https://colab.research.google.com/github/VishalPethkar/YBI-FOUNDCTION--2-MONTH--INTNSHIP/blob/main/01Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
diabetes = pd.read_csv(
    'https://github.com/YBIFoundation/Dataset/raw/main/Diabetes.csv'
)

# %%
diabetes.head()
# Out:
#    pregnancies  glucose  diastolic  triceps  insulin   bmi    dpf  age  \
# 0            6      148         72       35        0  33.6  0.627   50
# 1            1       85         66       29        0  26.6  0.351   31
# 2            8      183         64        0        0  23.3  0.672   32
# 3            1       89         66       23       94  28.1  0.167   21
# 4            0      137         40       35      168  43.1  2.288   33
#
#    diabetes
# 0         1
# 1         0
# 2         1
# 3         0
# 4         1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pregnancies  768 non-null    int64
#  1   glucose      768 non-null    int64
#  2   diastolic    768 non-null    int64
#  3   triceps      768 non-null    int64
#  4   insulin      768 non-null    int64
#  5   bmi          768 non-null    float64
#  6   dpf          768 non-null    float64
#  7   age          768 non-null    int64
#  8   diabetes     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        pregnancies     glucose   diastolic     triceps     insulin  \
# count   768.000000  768.000000  768.000000  768.000000  768.000000
# mean      3.845052  120.894531   69.105469   20.536458   79.799479
# std       3.369578   31.972618   19.355807   15.952218  115.244002
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       1.000000   99.000000   62.000000    0.000000    0.000000
# 50%       3.000000  117.000000   72.000000   23.000000   30.500000
# 75%       6.000000  140.250000   80.000000   32.000000  127.250000
# max      17.000000  199.000000  122.000000   99.000000  846.000000
#
#               bmi         dpf         age    diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
y = diabetes['diabetes']

# %%
X = diabetes.drop(['diabetes'], axis=1)

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------------- -------------------- 3.9/8.0 MB 19.6 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.0 MB 16.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 13.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/36.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/36.3 MB 11.6 MB/s eta 0:00:03
#    ------ --------------------------------- 5.5/36.3 MB 12.9 MB/s eta 0:00:03
#    --------- ------------------------------ 8.4/36.3 MB 13.0 MB/s eta 0:00:03
#    ------------ --------------------------- 11.8/36.3 MB 13.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 15.5/36.3 MB 14.1 MB/s eta 0:00:02
#    ------------------- -------------------- 17.6/36.3 MB 13.5 MB/s eta 0:00:02
#    --------------------- ------------------ 19.9/36.3 MB 13.1 MB/s eta 0:00:02
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.7,
    random_state=2529
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.7,
    random_state=2529
)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((537, 8), (231, 8), (537,), (231,))

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=500)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=500)

# %%
model.intercept_
model.coef_
# Out:
# array([[ 1.01212809e-01,  3.60559618e-02, -2.09754602e-02,
#         -2.57250334e-03, -2.04564603e-04,  8.24683197e-02,
#          9.51128784e-01,  2.53614205e-02]])

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[133,  12],
#        [ 41,  45]])

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7705627705627706

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.92      0.83       145
#            1       0.79      0.52      0.63        86
#
#     accuracy                           0.77       231
#    macro avg       0.78      0.72      0.73       231
# weighted avg       0.77      0.77      0.76       231
